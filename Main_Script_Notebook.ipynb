# %%
import pandas as pd
from scipy.stats import pearsonr

df = pd.read_csv("39-Versanddaten.csv", sep=";")

# %%
## 1 - Affichage des titres des colonnes, des 15 premières lignes et du 
## nombres d'enregistrements.

print(df.head(15))
print(f"\nLe nombre total d'enregistrement est de {len(df)}.")
# Out:
#     ID Transportmittel Priorität Geschlecht  Produktkosten  Rabatt  Gewicht
# 0    1          Flight       low          F            177      44     1233
# 1    2          Flight       low          M            216      59     3088
# 2    3          Flight       low          M            183      48     3374
# 3    4          Flight    medium          M            176      10     1177
# 4    5          Flight    medium          F            184      46     2484
# 5    6          Flight    medium          F            162      12     1417
# 6    7          Flight       low          F            250       3     2371
# 7    8          Flight       low          F            233      48     2804
# 8    9          Flight       low          F            150      11     1861
# 9   10          Flight    medium          F            164      29     1187
# 10  11          Flight    medium          M            189      12     2888
# 11  12          Flight    medium          F            232      32     3253
# 12  13          Flight    medium          F            198       1     3667
# 13  14          Flight      high          M            275      29     2602
# 14  15          Flight       low          M            152      43     1009
#
# Le nombre total d'enregistrement est de 200.

# %%
## 2 - Analyse univariée de chaque caractéristique métrique et affichage des
## résultats sous forme de tableau avec enregistrement dans un fichier.

data = df.describe().round(2).iloc[1:3,1:]
print(data)
with open("Résultats d'évaluation.txt", "w") as file:
    file.write(str(data))
# Out:
#       Produktkosten  Rabatt  Gewicht
# mean         188.20   33.36  2360.36
# std           44.49   18.73  1125.97

# %%
## 4 - Analyse de corrélation selon la méthode de Pearson

cout_produit = df["Produktkosten"]
poids = df["Gewicht"]

corr, _ = pearsonr(cout_produit, poids)
print("Le coefficient de corrélation entre le <cout du produit> et le <poids> vaut {:.3f}".format(corr))
if corr > -0.5 and corr < 0.5:
    print("Il s'agit d'une corrélation Faible.")
elif corr > -0.75 and corr < 0.75:
    print("Il s'agit d'une corrélation Moyenne.")
elif corr > -0.87 and corr < 0.87:
    print("Il s'agit d'une corrélation Forte.")
elif corr > -1 and corr < 1:
    print("Il s'agit d'une corrélation Très Forte.")
elif corr == 1 or corr == -1:
    print("Il s'agit d'une corrélation Parfaite.")
else:
    print("Il s'agit d'une corrélation Nulle.")
# Out:
# Le coefficient de corrélation entre le <cout du produit> et le <poids> vaut 0.494
# Il s'agit d'une corrélation Faible.

# %%
import matplotlib.pyplot as plt

# %%
## 5 - Régression linéaire avec 2 caractéristiques et présentation des résultats
## dans un diagramme de dispersion, et avec une droite de régression.

plt.scatter(df["Produktkosten"], df["Gewicht"])
plt.xlabel("Produktkosten")
plt.ylabel("Gewicht")
plt.title("Diagramme de Dispersion")
# Out:
# Text(0.5, 1.0, 'Diagramme de Dispersion')

# %%
import seaborn as sns

# %%
sns.lmplot(x="Produktkosten", y="Gewicht",data=df)
